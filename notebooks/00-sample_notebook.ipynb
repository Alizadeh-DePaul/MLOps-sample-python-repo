# %%
# Live-reload of imported modules
# %load_ext autoreload
# %autoreload 2

# Ensure that sample_package is importable
import sys
from pathlib import Path

REPO_DIR = str(Path("..").resolve())
if REPO_DIR not in sys.path:
    sys.path.insert(0, REPO_DIR)

from sample_package import SampleClass

# %%
sc = SampleClass()
print(f"sc.x = {sc.x}")
print(f"sc.sample_method() = {sc.sample_method()}")
